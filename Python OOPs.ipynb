# %% [markdown]
# 1. What is Object-Oriented Programming (OOP) ?
# Ans. Object-oriented programming (OOP) is a computer programming model that organizes software design around objects, rather than logic and functions. Objects are units that contain data and code, and are the building blocks of computer programs.

# %% [markdown]
# 2. What is a class in OOP ?
# Ans. In object-oriented programming (OOP), a class is a template that defines the methods and variables for a specific type of object.

# %% [markdown]
# 3. What is an object in OOP ?
# Ans. In object-oriented programming (OOP), an object is a unit of code that represents a real-world entity and is the basic building block of OOP applications.

# %% [markdown]
# 4.  What is the difference between abstraction and encapsulation ?
# Ans. In programming, abstraction and encapsulation are both techniques that help keep code organized and separate unrelated items. The main difference between the two is that abstraction focuses on what an object does, while encapsulation focuses on how an object's data is accessed and manipulated.

# %% [markdown]
# 5.What are dunder methods in Python?
# Ans.In Python, dunder methods (short for "double underscore methods") are special methods that start and end with double underscores (e.g., __init__, __str__, __add__). They allow you to customize the behavior of your classes and objects, enabling them to interact with built-in Python features and operators.

# %% [markdown]
# 6.Explain the concept of inheritance in OOP?
# Ans.In object-oriented programming (OOP), inheritance is a fundamental concept that allows a class to inherit properties and behaviors from another class:
# Explanation
# A class that inherits from another class is called a subclass or child class, while the class it inherits from is called a superclass or parent class. The subclass can extend the functionality of the superclass by adding new features or overriding existing ones.
# Benefits
# Inheritance promotes code reuse and establishes relationships between classes. It makes programming simpler and cleaner because you don't have to write the same code again for the new class.

# %% [markdown]
# 7.What is polymorphism in OOP ?
# Ans.Polymorphism is a concept in object-oriented programming (OOP) that allows objects of different types to be treated as objects of a common superclass. It's a key concept in OOP that enables code reusability and flexibility.

# %% [markdown]
# 8.How is encapsulation achieved in Python?
# Ans.Encapsulation in Python is achieved through the use of access modifiers, which control the visibility and accessibility of class members (attributes and methods). Here's how it works:
# Access Modifiers:
# Public:
# Members are accessible from anywhere, both inside and outside the class. By default, all members in Python are public.
# Protected:
# Members are accessible within the class and its subclasses. They are denoted by a single underscore (_) prefix.
# Private:
# Members are accessible only within the class. They are denoted by a double underscore (__) prefix.

# %% [markdown]
# 9.What is a constructor in Python?
# Ans.In Python, a constructor is a special method that is automatically called when an object of a class is created. It is used to initialize the attributes of the object.
# Key points:
# Method name: The constructor method is named __init__().
# Purpose: It initializes the object's state by assigning values to its data members.
# Automatic invocation: The constructor is called automatically when you create an object using the class.
# self parameter: The first parameter of the constructor is always self, which refers to the instance of the class being created.

# %% [markdown]
# 10.What are class and static methods in Python?
# Ans.The @classmethod decorator is a built-in function decorator that is an expression that gets evaluated after your function is defined. The result of that evaluation shadows your function definition. A class method receives the class as an implicit first argument, just like an instance method receives the instance.
#
# A static method does not receive an implicit first argument. A static method is also a method that is bound to the class and not the object of the class. This method can’t access or modify the class state. It is present in a class because it makes sense for the method to be present in class.

# %% [markdown]
# 11.What is method overloading in Python?
# Method overloading, in the traditional sense, isn't directly supported in Python like it is in languages like Java or C++. In those languages, you can define multiple methods with the same name but different parameter lists within the same class.
# However, Python achieves similar functionality through:
# Default Arguments:
# You can provide default values for parameters, allowing you to call a function with varying numbers of arguments.
# Variable-Length Arguments:
# Using *args and **kwargs allows you to pass an arbitrary number of positional and keyword arguments to a function.

# %% [markdown]
# 12.What is method overriding in OOP?
# Ans.Method overriding is a feature in object-oriented programming (OOP) that allows a subclass to replace a method in its superclass with its own implementation. The subclass method must have the same name, parameters, signature, and return type as the superclass method.
# Method overriding allows developers to customize the behavior of inherited methods without modifying the parent class's code. This enables polymorphism, which means that objects of different classes can be treated interchangeably based on their common parent class.

# %% [markdown]
# 13.What is a property decorator in Python?
# Ans.In Python, the @property decorator is a built-in feature that allows you to define methods that can be accessed as if they were attributes. This means you can add logic to getting, setting, or deleting an attribute without changing how the user interacts with the class.
# Benefits of using property decorators:
# Encapsulation:
# You can control access to attributes, ensuring that they are accessed and modified in a controlled manner. This can be useful for data validation, type checking, or other logic.
# Readability:
# You can use the dot notation to access methods as if they were attributes, making your code more concise and intuitive.
# Maintainability:
# You can change the internal implementation of your class without affecting external code that uses the class.

# %% [markdown]
# 14.Why is polymorphism important in OOP?
# Polymorphism is an important feature of object-oriented programming (OOP) because it allows for code reusability, flexibility, and extensibility:
# Code reusability
# Polymorphism allows multiple classes to implement the same method in different ways, which can save time and speed up development.
# Flexibility
# Polymorphism allows programmers to perform a single action in various ways, and to redefine methods for derived classes.
# Extensibility
# Polymorphism allows developers to easily create new classes derived from existing classes, without modifying the existing code.
# Readability
# Polymorphism can improve code readability by allowing functions to share the same name but have different arguments.
# Debugging
# Polymorphism simplifies variable searches and execution, as well as code debugging.

# %% [markdown]
# 15.What is an abstract class in Python?
# In Python, an abstract class is a class that cannot be instantiated on its own and is designed to be a blueprint for other classes (subclasses). It serves as a template, defining a common interface and structure that its subclasses must adhere to.
# Key points:
# Abstract methods:
# An abstract class contains one or more abstract methods, which are declared but not implemented. These methods must be implemented by any subclass that inherits from the abstract class.
# abc module:
# To create an abstract class, you need to use the abc module (Abstract Base Classes). This module provides the ABC class and the abstractmethod decorator.
# Enforcing structure:
# Abstract classes help ensure that subclasses provide the necessary functionality, promoting consistency and maintainability in your code.

# %% [markdown]
# 16.What are the advantages of OOP?
# Ans.Object-Oriented Programming (OOP) has many advantages, including:
# Modularity
# OOP allows developers to break down complex systems into smaller, more manageable objects. This makes it easier to troubleshoot and collaborate.
# Reusability
# OOP allows developers to reuse code through inheritance, saving time and effort.
# Flexibility
# OOP's polymorphism feature allows a single function to adapt to the class it's in. This makes it easier to scale and extend software systems.
# Security
# OOP's encapsulation feature bundles data to protect it from unintended corruption.
# Readability and maintainability
# OOP's clear structure makes it easier for developers to understand and modify existing code.
# Wide adoption
# OOP is supported by many popular programming languages, frameworks, and libraries.
# Ease of use
# OOP works well with IDEs, and developers have access to a wealth of resources, tools, and community support.
# Efficiency
# OOP is a top choice for developers who want to keep their code efficient and easy to work with.

# %% [markdown]
# 17.What is the difference between a class variable and an instance variable?
# Ans.The main difference between a class variable and an instance variable is that class variables are shared by all instances of a class, while instance variables are unique to each instance:
# Class variables
# A single copy of a class variable exists, regardless of how many instances of the class exist. Class variables are useful for sharing data between all instances of a class, such as keeping track of the number of instances created or storing a constant value.
# Instance variables
# Instance variables are created when an object is instantiated and are accessible to all the constructors, methods, or blocks in the class. Instance variables are useful for storing data that is specific to each instance, such as the name or age of a person.

# %% [markdown]
# 18.What is multiple inheritance in Python?
# Ans.Multiple inheritance in Python is a feature that allows a class to inherit from more than one parent class. This means that the child class can inherit attributes and methods from multiple sources, combining their functionalities.
#
# Key points:
# Syntax:
# To use multiple inheritance, simply list the parent classes in the class definition, separated by commas (e.g., class Child(Parent1, Parent2):).
# Method Resolution Order (MRO):
# Python uses a specific algorithm, called the C3 linearization algorithm, to determine the order in which methods are resolved in the case of inheritance conflicts. This ensures that the inheritance hierarchy is traversed in a predictable manner.
# super() function:
# The super() function is used to call methods from parent classes, which is especially useful in multiple inheritance scenarios where you need to access functionality from multiple parent classes.
# Diamond problem:
# Multiple inheritance can lead to the "diamond problem", where a class inherits from two parent classes that share a common ancestor. Python resolves this ambiguity using the MRO.

# %% [markdown]
# 19.Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
# ans. In Python, __str__ and __repr__ are special methods that allow you to define how an object is represented as a string. Here's an explanation of their purposes:
# __str__:
# Purpose: This method is used to create a human-readable string representation of an object. It's intended for end-users who want to see a clear and concise description of the object.
# Usage: The __str__ method is called when you use the str() function on an object or when you use the print() function to display the object.
#
#
# __repr__:
# Purpose: This method aims to provide a more detailed and unambiguous string representation of an object. It's intended for developers who need to see the object's internal structure or recreate the object from the string.
# Usage: The __repr__ method is called when you use the repr() function on an object or when you evaluate an object in the Python interpreter.

# %% [markdown]
# 20. What is the significance of the ‘super()’ function in Python?
# ans.In Python, the super() function is used to access methods and properties of a parent or superclass from a child or subclass. This is particularly useful when working with inheritance in object-oriented programming.
# Significance of super():
# Accessing Parent Class Methods:
# super() allows you to call methods defined in the parent class, even if those methods are overridden in the child class. This is especially important when you want to extend the functionality of a parent class method rather than completely replacing it.
# Avoiding Hardcoding Parent Class Names:
# By using super(), you don't need to explicitly mention the parent class name. This makes your code more maintainable and flexible, especially when dealing with multiple levels of inheritance.
# Multiple Inheritance:
# super() is crucial when working with multiple inheritance in Python. It helps to navigate the complex method resolution order (MRO) and ensures that the correct methods are called from the appropriate superclasses.

# %% [markdown]
# 21.What is the significance of the __del__ method in Python?
# ans.In Python, the __del__() method is a special method, also known as a destructor. It is called when an object is about to be destroyed.
# Significance:
# Cleanup:
# This method is typically used to perform any necessary cleanup operations before an object is removed from memory. This can include closing files, releasing network connections, or freeing up other resources held by the object.
# Finalization:
# It allows you to perform any final actions or logic that need to be executed when an object's lifecycle ends.

# %% [markdown]
# 22.What is the difference between @staticmethod and @classmethod in Python?
# ans. In Python, both @staticmethod and @classmethod are decorators used to define methods that operate on the class level rather than on instances of the class. However, they have key differences:
# @staticmethod
# Purpose: Used for methods that don't need to access or modify the class state or any instance state. They act like regular functions but are logically grouped within the class.
# Parameters: Doesn't take any implicit parameters like self or cls.
# Access: Can't access class attributes or instance attributes directly.
#
# @classmethod
# Purpose: Used for methods that need to access or modify the class state but not any specific instance state. They can be used for factory methods or other operations related to the class itself.
# Parameters: Takes cls as the first parameter, which refers to the class itself.
# Access: Can access class attributes but not instance attributes.

# %% [markdown]
# 23.How does polymorphism work in Python with inheritance?
# ans. Polymorphism in Python with inheritance works through a concept called method overriding.
# Here's how it works:
# Inheritance:
# You create a base class with a method, and then create one or more subclasses that inherit from the base class.
# Method Overriding:
# In the subclass, you can redefine the inherited method with a different implementation. This is called method overriding.
# Polymorphic Behavior:
# When you call the method on an object, Python determines the object's actual type at runtime and executes the appropriate method implementation. This allows you to use a single interface (the method name) to interact with objects of different types.

# %% [markdown]
# 24.What is method chaining in Python OOP?
# Ans.In Python OOP, method chaining is a technique where you call multiple methods on an object in a single line of code. This is achieved by having each method return the object itself (self).
# How it works:
# Return self:
# Each method within a class that you want to chain must return self. This ensures that the method call returns the object instance, allowing you to call another method on that same object directly.
# Chaining Calls:
# You can chain method calls by using the dot operator (.) after each method call.

# %% [markdown]
# 25.What is the purpose of the __call__ method in Python?
# ans. n Python, the __call__ method allows you to treat an object like a function. When you call an instance of a class that has a __call__ method defined, it's like calling a regular function.
# Here's what it does:
# Makes Objects Callable: It enables you to use objects as if they were functions.
# Customizes Object Behavior: You can define the behavior of the object when it's called.
# Flexible Design: It provides a way to create objects that behave like functions, offering more flexibility in your code design.

# %% [markdown]
# **Practical Questions**

# %%
#1Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!"
class Animal:
    def speak(self):
        print("Generic animal sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

# %%
#2Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# %%
#3 Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

# %%
#4 Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute

class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

# %%
#5 Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance
class BankAccount:
    def __init__(self, initial_balance=0):
        self._balance = initial_balance

# %%
#6 Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play()
class Instrument:
    def play(self):
        print("Generic instrument sound")
class Guitar(Instrument):
    def play(self):
        print("Guitar sound")
class Piano(Instrument):
    def play(self):
        print("Piano sound")

# %%
#7 Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# %%
#8 Implement a class Person with a class method to count the total number of persons created
class Person:
    count = 0
    def __init__(self):
        Person.count += 1
    @classmethod
    def get_count(cls):
        return cls.count

# %%
#9Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# %%
#10 Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

# %%
#11 Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old"
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
#12  Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades
    def average_grade(self):
        return sum(self.grades) / len(self.grades)

# %%
#13  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

# %%
#14 Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate
        def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

# %%
#15 Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
    def total_price(self):
        return self.price * self.quantity

# %%
#16 Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

# %%
#17  Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

# %%
#18 Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price
